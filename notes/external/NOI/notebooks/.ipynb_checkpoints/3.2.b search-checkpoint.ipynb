# %% [markdown]
# # 3.2.B Search

# %% [markdown]
# **Problem.** Given a finite sequence of numbers $a_1,\, \dots,\, a_n \in \mathbb{R}$ and an $x \in \mathbb{R}$, determine whether $x$ is in the sequence and if so, return the index of $x$ (i.e. an $i$ such that $a_i = a$).

# %% [markdown]
# Searching is a pretty foundational and easy to explain problem. You will often find yourself using this as a valuable component of other algorithms that you design. Often times designing a clever search space may even give you useful preliminary algorithm for your problem. We will see some examples of this sort.

# %% [markdown]
# ### Naive Search

# %% [markdown]
# We will first consider the setting where we have no _a priori_ knowledge about the sequence $a_1, \dots, a_n$. Particularly, we shall not be assuming that the sequence is sorted in any form.
#
# **What is a natural first attempt at a search algorithm? What is its worst case running time?**

# %%
def naive_search(seq):
    pass

# %% [markdown]
# ### Divide and Conquer: Binary Search

# %% [markdown]
# Now, suppose that the sequence is sorted. That is, $a_1 \le a_2 \le \dots \le a_n$.

# %% [markdown]
# ## Exercises
