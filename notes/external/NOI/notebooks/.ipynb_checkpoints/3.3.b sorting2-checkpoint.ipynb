# %% [markdown]
# # 3.3.B Sorting II: $\small{O(n \log n)}$ Runtime

# %% [markdown]
# ### Divide and Conquer: Merge Sort

# %% [markdown]
# ### A Family of Sorting Algorithms: Quick Sort

# %% [markdown]
# ### (Optional) Probabilistic Analysis of Quick Sort

# %% [markdown]
# ## Exercises
