# %% [markdown]
# # 3.3.A Sorting I: $\small{O(n^2)}$ Runtime

# %% [markdown]
# ### A First Sorting Algorithm: Bubblesort

# %% [markdown]
# ### More Sorts: Selection and Insertion Sort

# %% [markdown]
# ## Exercises
