# %% [markdown]
# # 4.1.A BFS II: Applications

# %% [markdown]
# ### Single Source Shortest Paths

# %% [markdown]
# ### Connected Components

# %% [markdown]
# ### $2$-Colorings and Bipartite Graphs

# %% [markdown]
# ## Exercises
