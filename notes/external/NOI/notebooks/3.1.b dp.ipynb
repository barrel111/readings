# %% [markdown]
# # 3.1.B Dynamic Programming

# %% [markdown]
# ### Memoizing Fibonacci.

# %% [markdown]
# ### DP I: Weighted Interval Scheduling.

# %% [markdown]
# ### Principle of Optimal Substructure.

# %% [markdown]
# ### DP II: Weighted Independent Set on a Path.

# %% [markdown]
# ## Coding Exercises

# %% [markdown]
# ### 1. WIS Implementation.

# %% [markdown]
# ### 2. Edit Distance.

# %% [markdown]
# ### 3. Coin Exchange.
