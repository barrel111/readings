# %% [markdown]
# # 3.2.A Complexity Analysis

# %% [markdown]
# ### Big-$\small\mathcal{O}$.

# %% [markdown]
# ### Emperical Verification.

# %% [markdown]
# ### Caveat emptor. Hidden Constants.

# %% [markdown]
# ## Exercises
