# %% [markdown]
# # 4.1.B DFS II: Applications

# %% [markdown]
# ### Topological Sorting I: DFS

# %% [markdown]
# ### (Optional) Topological Sorting II: Kahn's

# %% [markdown]
# ### Strongly Connected Components

# %% [markdown]
# ### Bridges

# %% [markdown]
# ## Exercises
